# %%
# Quiz Questions
questions = [
    {
        "question": "Which of the following is the correct extension of the Python file?",
        "options": ["A. .python", "B. .pl", "C. .py", "D. .p"],
        "answer": "C"
    },
    {
        "question": "Which type of Programming does Python support?",
        "options": ["A. object-oriented programming", "B. structured programming", "C. functional programming", "D. all of the mentioned"],
        "answer": "D"
    },
    {
        "question": "Is Python code compiled or interpreted?",
        "options": ["A. Python code is both compiled and interpreted", "B. Python code is neither compiled nor interpreted", "C. Python code is only compiled", "D. Python code is only interpreted"],
        "answer": "A"
    },
    {
        "question": "All keywords in Python are in _________",
        "options": ["A. Capitalized", "B. lower case", "C. UPPER CASE", "D. None of the mentioned"],
        "answer": "D"
    },
    {
        "question": "Which keyword is used for function in Python language?",
        "options": ["A. Function", "B. def", "C. Fun", "D. Define"],
        "answer": "B"
    },
    {
        "question": "Which of the following statements is used to create an empty set in Python",
        "options": ["A. ( )", "B. [ ]", "C.{ }", "D. set()"],
        "answer": "D"
    },
    {
        "question": "Which of the following functions is a built-in function in python language?",
        "options": ["A. val()", "B. print()", "C. printf()", "D. None of these"],
        "answer": "B"
    },
    {
        "question": "What is the maximum length of a Python identifier??",
        "options": ["A. 32", "B. 16", "C.128", "D. No fixed length is specified"],
        "answer": "D"
    },
    {
        "question": "Which of the following types of loops are not supported in Python?",
        "options": ["A. for", "B. while ", "C. do-while", "D. None of these"],
        "answer": "C"
    },
    {
        "question": "Which of the following are valid string manipulation functions in Python?",
        "options": ["A. count", "B. upper", "C. strip", "D. all the above"],
        "answer": "D"
    }
]

# Quiz Game Function
def quiz_game():
    print("Welcome to the Quiz Game!")
    print("Answer the questions by typing the letter of the correct option (A, B, C, or D).\n")
    
    score = 0
    question_number = 1
    
    for q in questions:
        print(f"Question {question_number}: {q['question']}")
        
        for option in q["options"]:
            print(option)
        
        answer = input("Your answer: ").strip().upper()  # Normalize input
        
        if answer == q["answer"]:
            print("Correct!\n")
            score += 10
        else:
            print(f"Wrong! The correct answer was {q['answer']}.\n")
        
        question_number += 1
    
    print(f"Quiz Over! Your total score is: {score}/100")
    
    if score == 100:
        print("Excellent! You got everything right!")
    elif score >= 70:
        print("Good job!")
    else:
        print("Better luck next time!")

# Start the game
if __name__ == "__main__":
    quiz_game()
# Out:
# Welcome to the Quiz Game!
# Answer the questions by typing the letter of the correct option (A, B, C, or D).
#
# Question 1: Which of the following is the correct extension of the Python file?
# A. .python
# B. .pl
# C. .py
# D. .p
# Correct!
#
# Question 2: Which type of Programming does Python support?
# A. object-oriented programming
# B. structured programming
# C. functional programming
# D. all of the mentioned
# Wrong! The correct answer was D.
#
# Question 3: Is Python code compiled or interpreted?
# A. Python code is both compiled and interpreted
# B. Python code is neither compiled nor interpreted
# C. Python code is only compiled
# D. Python code is only interpreted
# Correct!
#
# Question 4: All keywords in Python are in _________
# A. Capitalized
# B. lower case
# C. UPPER CASE
# D. None of the mentioned
# Correct!
#
# Question 5: Which keyword is used for function in Python language?
# A. Function
# B. def
# C. Fun
# D. Define
# Wrong! The correct answer was D.
#
# ...
